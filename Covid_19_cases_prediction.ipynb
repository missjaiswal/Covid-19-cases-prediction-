# %% [markdown]
# <a href="https://colab.research.google.com/github/missjaiswal/Covid-19-cases-prediction-/blob/main/Covid_19_cases_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df=pd.read_csv("lrdata.csv")
df
# Out:
#       cases  increasingrate  decreasingrate         time
# 0        18          15.960           53.13   1121.87390
# 1        21          16.815           52.58   1131.50660
# 2        38          16.815           50.38   1135.94070
# 3        26          17.195           49.06   1136.39940
# 4        18          17.290           48.07   1137.01100
# ...     ...             ...             ...          ...
# 1333     46          48.070            2.30  55135.40209
# 1334     58          49.060            1.70  58571.07448
# 1335     23          50.380            1.43  60021.39897
# 1336     22          52.580            1.30  62592.87309
# 1337     18          53.130            0.90  63770.42801
#
# [1338 rows x 4 columns]

# %%
df.head()
# Out:
#    cases  increasingrate  decreasingrate       time
# 0     18          15.960           53.13  1121.8739
# 1     21          16.815           52.58  1131.5066
# 2     38          16.815           50.38  1135.9407
# 3     26          17.195           49.06  1136.3994
# 4     18          17.290           48.07  1137.0110

# %%
X=df[['cases', 'increasingrate', "decreasingrate"]] #independent variables
y=df[['time']] #dependent variable

# %%
def case(X,y):
  from sklearn.linear_model import LinearRegression
  reg=LinearRegression()
  reg.fit(X,y)
  return reg

# %%
X_train, X_test, y_train, y_test=model_selection.train_test_split(X,y)

# %%
reg=case(X_train, y_train)

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([[ -723.72220251],
#        [ 3667.59173107],
#        [10884.75007528],
#        [24607.08360042],
#        [25424.92872018],
#        [ 3163.99460577],
#        [20249.04721878],
#        [ 7288.29096758],
#        [17233.90018913],
#        [-3913.41169079],
#        [ 8394.79582733],
#        [-2915.09591027],
#        [15291.95045025],
#        [ 7628.26161546],
#        [19099.67492853],
#        [34539.37175939],
#        [ 7293.80549745],
#        [14865.56208852],
#        [ 8988.24294566],
#        [18551.0587631 ],
#        [11586.93853241],
#        [18739.15901369],
#        [15325.21150742],
#        [-2767.13739384],
#        [12373.15659189],
#        [12099.04036943],
#        [24618.07420765],
#        [14321.23771879],
#        [24179.42827168],
#        [14290.34814778],
#        [30248.59246833],
#        [-5920.01488277],
#        [31353.05784882],
#        [18533.60438481],
#        [14699.64630357],
#        [ 1481.05725293],
#        [38592.24017893],
# ...

# %%
reg.score(X_test, y_test)
# Out:
# 0.857566990626038

# %%
plt.figure(figsize=(20,10))
plt.plot(X, reg.predict(X),"*")
plt.title("Covid-19 cases prediction", fontsize=15)
plt.xlabel("Cases rate", fontsize=15)
plt.ylabel("Time", fontsize=15)
plt.legend(labels=["cases", "increasing rate", "decreasing rate"], fontsize=14)
plt.plot()
# Out:
# []
